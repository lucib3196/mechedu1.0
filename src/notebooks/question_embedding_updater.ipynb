# %% [markdown]
# # Question Embedding Updater
# **Description:**
# This Jupyter notebook is designed to streamline the process of updating training data for question generation. By uploading a folder containing questions and their associated files, the notebook will extract the relevant content, generate embeddings, and compile the data into a CSV file. This CSV will serve as the updated training dataset, ready for use in the question generation.

# %% [markdown]
# ## Part 1: Upload Folder and Extract Content
# Just change the path to the folder containing all the data.

# %%
import os
import pandas as pd
from typing import Dict

def extract_questions_to_dataframe(directory_path: str) -> pd.DataFrame:
    """
    Extracts questions and their associated files from a directory structure and 
    organizes the data into a Pandas DataFrame where columns represent question titles.
    
    Args:
        directory_path (str): The path to the root directory containing question folders.
        
    Returns:
        pd.DataFrame: A DataFrame with question titles as rows
    """
    data = {}  # Dictionary to store data for each question title
    
    # Traverse the directory structure
    for current_path, subdirectories, filenames in os.walk(directory_path):
        # Check if the current directory is a leaf directory (no subdirectories)
        if not subdirectories:
            question_title = os.path.basename(current_path)  # Use directory name as question title
            
            # Store file contents for the current question
            file_contents = {}
            for filename in filenames:
                file_path = os.path.join(current_path, filename)
                try:
                    with open(file_path, 'r') as file:
                        file_contents[filename] = file.read()
                except Exception as e:
                    print(f"Error reading file {file_path}: {e}")
            
            # Add the file contents to the data dictionary under the question title
            data[question_title] = file_contents
    
    # Create a DataFrame with columns as question titles
    df = pd.DataFrame.from_dict(data, orient='index')
    return df
path = r"C:\Users\lberm\Downloads\ME175-20241228T184344Z-001"
df = extract_questions_to_dataframe(path)
df.rename_axis("question_title", axis='index',inplace=True)
df.head()
# Out:
#                                                              info.json  \
# question_title
# ddSwitchToSL         {\n    "title": "DoubleDecliningBalanceDepreci...
# doubleDecline        {\n    "title": "DoubleDecliningBalanceDepreci...
# MARCSDeduction5year  {\n    "title": "MacrsDepreciationCalculation"...
# MARCSDeduction7year  {\n    "title": "MacrsDepreciationCalculation"...
# straightLineMethod   {\n    "title": "MillingMachineDepreciation",\...
#
#                                                          question.html  \
# question_title
# ddSwitchToSL         <pl-question-panel>\n    <p>Create a table sho...
# doubleDecline        <pl-question-panel>\n    <p>Create a table sho...
# MARCSDeduction5year  <pl-question-panel>\n    <p>Using the MACRS de...
# MARCSDeduction7year  <pl-question-panel>\n    <p>Using the MACRS de...
# straightLineMethod   <pl-question-panel>\n    <p>A milling machine ...
#
#                                                              server.js  \
# question_title
# ddSwitchToSL         const math = require('mathjs'); \n\nconst gene...
# doubleDecline        const math = require('mathjs');\n//const { bve...
# MARCSDeduction5year  const math = require('mathjs');\n\nconst MACRS...
# MARCSDeduction7year  const math = require('mathjs');\n\nconst MACRS...
# straightLineMethod   const math = require('mathjs');\n\nconst gener...
#
#                                                          solution.html
# question_title
# ddSwitchToSL         <pl-solution-panel>\n   \n        <pl-hint lev...
# doubleDecline        <pl-solution-panel>\n    <pl-hint level="1" da...
# MARCSDeduction5year  <pl-solution-panel>\n    <pl-hint level="1" da...
# MARCSDeduction7year  <pl-solution-panel>\n    <pl-hint level="1" da...
# straightLineMethod   <pl-solution-panel>\n    <pl-hint level="1" da...

# %% [markdown]
# ## Part 2: Creating a batch file

# %%
from dotenv import load_dotenv
from openai import OpenAI
load_dotenv()
client = OpenAI(api_key = os.environ.get('OPENAI_API_KEY'))

# %%
question_prompt = """
    The following is an html document containing a questio, you are tasked with extracting the question 
    and format it such that it looks like it comes from a textbook or official material. The output should be 
    1. Maintain the Original Structure: Ensure the extracted question retains its original structure, including any subsections, numbered parts, or bullet points.
    2. Enhance Formatting for Readability: Format the question to appear polished and professional, akin to a textbook or exam guide. Use clear sectioning, appropriate indentation, and consistent stylin
    3. Ensure Completeness: Verify that each question has all necessary components (e.g., instructions, given data, diagrams, or conditions) to be fully understood without additional context.
    4. Preserve Essential Elements: Retain mathematical symbols, figures, or any special formatting provided in the HTML. Delimit any latext using $$ for block level math and $ for inline math. 
    
    html:{html}
"""
# question_prompt.format(html = df.iloc[0]["question.html"])

def clean_question(html:str):
    question_prompt = r"""
    The following is an html document containing a questio, you are tasked with extracting the question 
    and format it such that it looks like it comes from a textbook or official material. The output should be 
    1. Maintain the Original Structure: Ensure the extracted question retains its original structure, including any subsections, numbered parts, or bullet points.
    2. Enhance Formatting for Readability: Format the question to appear polished and professional, akin to a textbook or exam guide. Use clear sectioning, appropriate indentation, and consistent stylin
    3. Ensure Completeness: Verify that each question has all necessary components (e.g., instructions, given data, diagrams, or conditions) to be fully understood without additional context.
    4. Preserve Essential Elements: Retain mathematical symbols, figures, or any special formatting provided in the HTML. Delimit any latext using $$ for block level math and $ for inline math. 
    5. The hmtl will contain placeholders in the format {{params.value}} replace these values with appropriate values
    Only Return the formatted question
    """
    
    completion = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "developer", "content": "You are a helpful assistant."},
        {"role": "user", "content": question_prompt+ f'\n html:{html}'}])
    
    return completion.choices[0].message.content

random_index = df.sample(n=3).index
for id in random_index:
    original_question = df.loc[id]['question.html']
    cleaned_question = clean_question(original_question)
    msg = f"""
    \nQuestion{id}
    Original Question: {original_question}\n
    Cleaned Question {cleaned_question}\n
    """
    print(msg)
# Out:
#
# QuestionMARCSDeduction5year
#     Original Question: <pl-question-panel>
#     <p>Using the MACRS deduction method for a large tape-drive system purchased for {{params.cost}} USD classified as {{params.propertyClass}}-year property, calculate the depreciation expense and the book value of the system at the end of each year for its {{params.usefulLife}}-year useful life.</p>
# </pl-question-panel>
#
# <pl-number-input answers-name="bookValueEndYear1" comparison="sigfig" digits="3" label="Book Value at End of Year 1 "></pl-number-input>
# <pl-number-input answers-name="bookValueEndYear2" comparison="sigfig" digits="3" label="Book Value at End of Year 2 "></pl-number-input>
# <pl-number-input answers-name="bookValueEndYear3" comparison="sigfig" digits="3" label="Book Value at End of Year 3 "></pl-number-input>
# <pl-number-input answers-name="bookValueEndYear4" comparison="sigfig" digits="3" label="Book Value at End of Year 4 "></pl-number-input>
#
# <pl-number-input answers-name="bookValueEndYearendend" comparison="sigfig" digits="3" label="Book Value at End of Year {{params.endend}} "></pl-number-input>
# <pl-number-input answers-name="bookValueEndYearend" comparison="sigfig" digits="3" label="Book Value at End of Year {{params.end}} "></pl-number-input>
#
#     Cleaned Question **Depreciation Calculation Using MACRS Method**
#
# A large tape-drive system has been purchased for **$50,000 USD** and is classified as a **5-year property**. You are tasked with calculating the depreciation expense and the book value of the system at the end of each year for its **5-year useful life**.
#
# **Instructions:**
#
# 1. **Utilize the MACRS Deduction Method**:
#    - Follow the Modified Accelerated Cost Recovery System (MACRS) to compute the depreciation expense for each year.
#    - Refer to MACRS depreciation tables for the applicable percentages based on a 5-year property class.
#
# 2. **Calculate the Book Value**:
#    - Determine the book value at the end of each year using the formula:
#      $$ \text{Book Value}_{\text{End of Year}} = \text{Cost} - \sum (\text{Depreciation Expenses}) $$
#
# **Tasks:**
#
# - **Book Value Calculations**:
#
#   - Compute the Book Value at the End of Year 1.
#
#   - Compute the Book Value at the End of Year 2.
#
#   - Compute the Book Value at the End of Year 3.
#
#   - Compute the Book Value at the End of Year 4.
#
#   - Compute the Book Value at the End of Year 5 (End of Useful Life).
#
# **Note**: Ensure that your calculations reflect the applicable MACRS percentages for each respective year in the asset's class life.
#
#
#
#
# QuestionIntrestPayed
#     Original Question: <pl-question-panel>
#   <p> You purchase a home with a {{params.interestRate}}% per year fixed-rate, {{params.loanTerm}}-year mortgage. Interest is compounded monthly. The amount borrowed is ${{params.amountBorrowed}}$ USD. </p>
#   <p> What is the total amount of interest paid over the life of the loan? </p>
# </pl-question-panel>
#
# <pl-number-input answers-name="intrestPayed" comparison="sigfig" digits="3" label="Total Interest = "></pl-number-input>
#
#     Cleaned Question ### Question
#
# You purchase a home with a fixed-rate mortgage at an interest rate of 4% per year for a term of 30 years. The interest is compounded monthly, and the amount borrowed is \$300,000 USD.
#
# 1. **Objective**
#    - Determine the total amount of interest paid over the life of the loan.
#
# 2. **Given Data**
#    - **Interest Rate**: 4% per annum
#    - **Loan Term**: 30 years
#    - **Compounding Frequency**: Monthly
#    - **Amount Borrowed**: \$300,000 USD
#
# 3. **Instructions**
#    - Calculate the total interest using the details provided.
#    - Note: Use the formula for monthly compounding when calculating the total interest paid.
#
# > **Answer Format**:
# > Total Interest Paid = (in USD)
#
# ---
#
# Ensure all calculations account for the fixed-rate and compounding nature of the interest over the specified loan term.
#
#
#
#
# QuestionstraightLineMethod
#     Original Question: <pl-question-panel>
#     <p>A milling machine is purchased for {{params.initial_cost}} USD at EOY 0. The machine is expected to have a {{params.life_span}}-year life and a salvage value of {{params.salvage_value}} USD. </p>
#
#         <p> Create a table showing the depreciation and book value for each year (i.e., from EOY 0 through EOY {{params.life_span}}) using straight-line depreciation. What is the book value at EOY {{params.mid}} and EOY {{params.eoy}}?</p>
# </pl-question-panel>
#
#
# <pl-number-input answers-name="book_value_eoymid" comparison="sigfig" digits="3" label="Book Value at EOY {{params.mid}} ="></pl-number-input>
# <pl-number-input answers-name="book_value_eoy" comparison="sigfig" digits="3" label="Book Value at EOY {{params.eoy}} ="></pl-number-input>
#
#
#     Cleaned Question **Depreciation and Book Value Analysis for a Milling Machine**
#
# A milling machine is purchased for $20,000$ USD at EOY 0. The machine is expected to have a $5$-year life and a salvage value of $2,000$ USD.
#
# 1. **Task**:
#    - Create a table showing the depreciation and book value for each year (i.e., from EOY 0 through EOY 5) using straight-line depreciation.
#
# 2. **Calculation Requirements**:
#    - Find the book value at EOY 3 and EOY 5.
#
# **Instructions**:
# - Straight-line depreciation is calculated as:
#
# \[ \text{Depreciation per Year} = \frac{\text{Initial Cost} - \text{Salvage Value}}{\text{Useful Life}} \]
#
# - Calculate the book value for each year and construct the table accordingly.
#
# **Input Sections**:
# - Book Value at EOY 3: [Enter your answer]
# - Book Value at EOY 5: [Enter your answer]

# %%
import json
from pydantic import BaseModel,Field
import os 


class Question(BaseModel):
    question: str=Field(...,description="The extracted question")

def create_request(content, custom_id):
    """
    Create a JSON request body for the chat completion API.

    Args:
        content (str): The content of the user message.
        custom_id (str): A custom identifier for the request.

    Returns:
        str: A JSON-formatted string for the request body.
    """
    request = {
        "custom_id": str(custom_id),
        "method": "POST",
        "url": "/v1/chat/completions",
        "body": {
            "model": "gpt-4o-mini",
            "messages": [
                {
                    "role": "system",
                    "content": "You are a helpful assistant."
                },
                {
                    "role": "user",
                    "content": content
                }
            ],
            "response_format": {
                "type": "json_schema",
                "json_schema": {
                    "name": "response",
                    "schema": Question.schema()
                }
            }
        }
    }
    return json.dumps(request, indent=4)
def save_as_jsonl(data, filename):
    """
    Save a list of JSON strings as a JSONL file.

    Args:
        data (list): A list of JSON strings.
        filename (str): The name of the file to save the data.

    Returns:
        None
    """
    with open(filename, 'w') as jsonl_file:
        for item in data:
            # Parse the string to a JSON object, then dump it back as a single line
            json_obj = json.loads(item)
            jsonl_file.write(json.dumps(json_obj) + '\n')

question_prompt = r"""
The following is an HTML document containing a question. You are tasked with extracting the question and formatting it such that it retains the same structure, removing any unnecessary HTML, and cleaning it up to look polished and professional.

The output should:
1. **Maintain the Original Structure**: Ensure the extracted question retains its original structure, including any subsections, numbered parts, or bullet points.
2. **Enhance Formatting for Readability**: Format the question to appear polished and professional, akin to a textbook or official material. Use clear sectioning, appropriate indentation, and consistent styling.
3. **Ensure Completeness**: Verify that each question has all necessary components (e.g., instructions, given data, diagrams, or conditions) to be fully understood without additional context.
4. **Preserve Essential Elements**: Retain mathematical symbols, figures, or any special formatting provided in the HTML. Delimit any LaTeX using `$$` for block-level math and `$` for inline math.
5. **Replace Placeholders**: The HTML may contain placeholders in the format `{{params.value}}`. Replace these placeholders with appropriate values based on the context. Ensure that all of them are replaced 

Example Input 1:
<p>Calculate the force exerted by an object using Newton's Second Law, where mass = {{params.mass}} kg and acceleration = {{params.acceleration}} m/s².</p>

Example Output 1:
Calculate the force exerted by an object using Newton's Second Law, where:
- Mass = 5 kg
- Acceleration = 3 m/s².

---

Example Input 2:
<p>A rectangular prism has a length of {{params.length}} cm, a width of {{params.width}} cm, and a height of {{params.height}} cm. Calculate its volume.</p>

Example Output 2:
A rectangular prism has a length of 10 cm, a width of 4 cm, and a height of 5 cm. Calculate its volume.

---

Example Input 3:
<p>What is the result of the following integral? $$\int_{{{params.lower_limit}}}^{{{params.upper_limit}}} x^2 \, dx$$</p>

Example Output 3:
What is the result of the following integral? 
$$\int_{0}^{3} x^2 \, dx$$

---

Ensure the output question retains the same structure, but remove unnecessary HTML and clean up the text to make it polished and professional. Only return the formatted question.
"""

    
request = []
for i, (index, row) in enumerate(df.iterrows(), start=1):
    question_title = index
    data = row.to_dict()
    question_html = data.get('question.html','')
    content = question_prompt+f'\nhtml{question_html}\n'
    request.append(create_request(content,question_title))
# Check base directory as thats where its probably saved
save_as_jsonl(request,'175batch.jsonl')

# %%
from openai import OpenAI
import os
client = OpenAI()

print(os.getcwd())
batch_input_file = client.files.create(
    file=open(os.path.join(os.getcwd(),"175batch.jsonl"), "rb"),
    purpose="batch"
)

print(batch_input_file)
batch_input_file_id = batch_input_file.id
client.batches.create(
    input_file_id=batch_input_file_id,
    endpoint="/v1/chat/completions",
    completion_window="24h",
    metadata={
        "description": "update"
    }
)
# Out:
# c:\Users\lberm\OneDrive\Documents\Github\mechedu1.0\src\notebooks
# FileObject(id='file-L2iTJhJs9ffYTUpwgxMsiy', bytes=124454, created_at=1735584207, filename='175batch.jsonl', object='file', purpose='batch', status='processed', status_details=None)
# Batch(id='batch_6772e9d09e888190b908158aa8bce19b', completion_window='24h', created_at=1735584208, endpoint='/v1/chat/completions', input_file_id='file-L2iTJhJs9ffYTUpwgxMsiy', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1735670608, failed_at=None, finalizing_at=None, in_progress_at=None, metadata={'description': 'update'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))

# %%
batch = client.batches.retrieve("batch_6772e9d09e888190b908158aa8bce19b")
print(batch)
# Out:
# Batch(id='batch_6772e9d09e888190b908158aa8bce19b', completion_window='24h', created_at=1735584208, endpoint='/v1/chat/completions', input_file_id='file-L2iTJhJs9ffYTUpwgxMsiy', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1735585883, error_file_id=None, errors=None, expired_at=None, expires_at=1735670608, failed_at=None, finalizing_at=1735585878, in_progress_at=1735584209, metadata={'description': 'update'}, output_file_id='file-RjyXfu2NfEpZ78hWpu3WSt', request_counts=BatchRequestCounts(completed=33, failed=0, total=33))

# %% [markdown]
# ### Part 3: Merging Data

# %%
file_response = client.files.content("file-RjyXfu2NfEpZ78hWpu3WSt")
data = {}
for line in file_response.text.split('\n'):
    line = line.strip()
    if line:  
        try:
            content = json.loads(line)
            question_id = content["custom_id"]
            completion = json.loads(content["response"]["body"]["choices"][0]["message"]["content"]).get('question')
            data[question_id] = completion
        except json.JSONDecodeError as e:
            print(f"Skipping invalid JSON line: {line} | Error: {e}")
df_batch = pd.DataFrame.from_dict(data, orient='index')

# %%
df_batch.head()
# Out:
#                                                                      0
# ddSwitchToSL         Create a table showing the depreciation and bo...
# doubleDecline        Create a table showing the depreciation and bo...
# MARCSDeduction5year  Using the MACRS deduction method for a large t...
# MARCSDeduction7year  Using the MACRS deduction method for a large t...
# straightLineMethod   A milling machine is purchased for 15,000 USD ...

# %%
new_df = pd.merge(df, df_batch, left_index=True, right_index=True)
new_df.head()
# Out:
#                                                              info.json  \
# ddSwitchToSL         {\n    "title": "DoubleDecliningBalanceDepreci...
# doubleDecline        {\n    "title": "DoubleDecliningBalanceDepreci...
# MARCSDeduction5year  {\n    "title": "MacrsDepreciationCalculation"...
# MARCSDeduction7year  {\n    "title": "MacrsDepreciationCalculation"...
# straightLineMethod   {\n    "title": "MillingMachineDepreciation",\...
#
#                                                          question.html  \
# ddSwitchToSL         <pl-question-panel>\n    <p>Create a table sho...
# doubleDecline        <pl-question-panel>\n    <p>Create a table sho...
# MARCSDeduction5year  <pl-question-panel>\n    <p>Using the MACRS de...
# MARCSDeduction7year  <pl-question-panel>\n    <p>Using the MACRS de...
# straightLineMethod   <pl-question-panel>\n    <p>A milling machine ...
#
#                                                              server.js  \
# ddSwitchToSL         const math = require('mathjs'); \n\nconst gene...
# doubleDecline        const math = require('mathjs');\n//const { bve...
# MARCSDeduction5year  const math = require('mathjs');\n\nconst MACRS...
# MARCSDeduction7year  const math = require('mathjs');\n\nconst MACRS...
# straightLineMethod   const math = require('mathjs');\n\nconst gener...
#
#                                                          solution.html  \
# ddSwitchToSL         <pl-solution-panel>\n   \n        <pl-hint lev...
# doubleDecline        <pl-solution-panel>\n    <pl-hint level="1" da...
# MARCSDeduction5year  <pl-solution-panel>\n    <pl-hint level="1" da...
# MARCSDeduction7year  <pl-solution-panel>\n    <pl-hint level="1" da...
# straightLineMethod   <pl-solution-panel>\n    <pl-hint level="1" da...
#
#                                                                      0
# ddSwitchToSL         Create a table showing the depreciation and bo...
# doubleDecline        Create a table showing the depreciation and bo...
# MARCSDeduction5year  Using the MACRS deduction method for a large t...
# MARCSDeduction7year  Using the MACRS deduction method for a large t...
# straightLineMethod   A milling machine is purchased for 15,000 USD ...

# %% [markdown]
# ### Creating embeddings

# %%
new_df.rename(columns={0: 'question'}, inplace=True)
new_df.iloc[2].question
# Out:
# 'Using the MACRS deduction method for a large tape-drive system purchased for 50,000 USD classified as 5-year property, calculate the depreciation expense and the book value of the system at the end of each year for its 7-year useful life.\n\nCalculate the following:\n- Book Value at End of Year 1 \n- Book Value at End of Year 2 \n- Book Value at End of Year 3 \n- Book Value at End of Year 4 \n- Book Value at End of Year 5 \n- Book Value at End of Year 6 \n- Book Value at End of Year 7.'

# %%
def create_request_batch(content, custom_id):
    """
    Create a JSON request body for the chat completion API.

    Args:
        content (str): The content of the user message.
        custom_id (str): A custom identifier for the request.

    Returns:
        str: A JSON-formatted string for the request body.
    """
    request = {
        "custom_id": str(custom_id),
        "method": "POST",
        "url": "/v1/embeddings",
        "body": {
            "model": "text-embedding-3-small",
            "input": content
            }
        }
    return json.dumps(request, indent=4)
request = []
for i, (index, row) in enumerate(new_df.iterrows(), start=1):
    question_title = index
    data = row.to_dict()
    question = data.get('question','')
    print(question)
    request.append(create_request_batch(question,question_title))
print(request)
# Check base directory as thats where its probably saved
save_as_jsonl(request,'175batch_embedding.jsonl')
# Out:
# Create a table showing the depreciation and book value for each year (i.e., from EOY 0 through EOY 10) for a milling machine purchased for 20000 USD with a salvage value of 2000 USD and a useful life of 10 years using double declining balance depreciation and switching to straight-line depreciation.
#
# What is the book value at EOY 1, EOY 5, and EOY 10?
#
# - Book Value at EOY 1 =
# - Book Value at EOY 5 =
# - Book Value at EOY 10 =
# Create a table showing the depreciation and book value for each year (i.e., from EOY 0 through EOY 10) for a milling machine purchased for 50000 USD with a salvage value of 5000 USD and a useful life of 10 years using double declining balance depreciation.
#
# What is the book value at EOY 1, EOY 5, and EOY 10?
#
# - Book Value at EOY 1 = 45000
# - Book Value at EOY 5 = 25000
# - Book Value at EOY 10 = 5000
# Using the MACRS deduction method for a large tape-drive system purchased for 50,000 USD classified as 5-year property, calculate the depreciation expense and the book value of the system at the end of each year for its 7-year useful life.
#
# Calculate the following:
# - Book Value at End of Year 1
# - Book Value at End of Year 2
# - Book Value at End of Year 3
# - Book Value at End of Year 4
# - Book Value at End of Year 5
# - Book Value at End of Year 6
# - Book Value at End of Year 7.
# Using the MACRS deduction method for a large tape-drive system purchased for {{params.cost}} USD, classified as {{params.propertyClass}}-year property, calculate the depreciation expense and the book value of the system at the end of each year for its {{params.usefulLife}}-year useful life.
#
# ### Book Value Calculations:
# - **Book Value at End of Year 1:**  {{bookValueEndYear1}}
# - **Book Value at End of Year 2:**  {{bookValueEndYear2}}
# - **Book Value at End of Year 3:**  {{bookValueEndYear3}}
# - **Book Value at End of Year 4:**  {{bookValueEndYear4}}
# - **Book Value at End of Year 5:**  {{bookValueEndYear5}}
# - **Book Value at End of Year 6:**  {{bookValueEndYear6}}
# - **Book Value at End of Year {{params.endend}}:**  {{bookValueEndYearendend}}
# - **Book Value at End of Year {{params.end}}:**  {{bookValueEndYearend}}
# A milling machine is purchased for 15,000 USD at EOY 0. The machine is expected to have a 10-year life and a salvage value of 2,000 USD.
#
# Create a table showing the depreciation and book value for each year (i.e., from EOY 0 through EOY 10) using straight-line depreciation. What is the book value at EOY 5 and EOY 10?
# You purchase a home with a 3%/year fixed-rate, 30-year mortgage. Interest is compounded monthly. The amount borrowed is $250,000. Every 3 months, you make an additional quarter payment which is used to pay off principal (e.g., at EOM 1 payment = A, at EOM 2 payment = A, at EOM 3 payment = 1.25A).
#
# Calculate how many months it will take to pay off the mortgage considering both the monthly payments and the additional quarterly payments.
# You are considering purchasing a new car from Slimy’s Sports Car Emporium. The car costs 25,000 USD, and you put a down payment of 5,000 USD. Slimy is offering Henry a 60 month loan with an interest rate of 6% per year compounded monthly with a payment of 500 USD.
#
# Something feels off about the monthly payment. Do some investigating and figure out what the monthly payment should be. How much money are they overcharging you per month?
# If you deposit 500 USD every other month into an account that pays 5% per year compounded monthly, how much will you have after 10 years? The first payment is made at the end of month 2.
#
# Hint: compute an effective interest rate.
# A loan has a nominal interest rate of 5% per year compounded monthly. What is the effective annual interest rate?
#
# ---
#
# A loan with interest that is compounded monthly has an effective annual interest rate of 8% . What is the nominal interest rate?
# You purchase a home with a **{{params.interestRate}}%** per year fixed-rate, **{{params.loanTerm}}-year** mortgage. Interest is compounded monthly. The amount borrowed is **${{params.amountBorrowed}} USD**.
#
# What is the total amount of interest paid over the life of the loan?
# If a loan amount of 1000 is received at t=0, and is repaid with a single payment of 1100 at t=6 months, what is the interest rate for the single 6-month compounding period?
#
# If the borrower is unable to pay off the loan until t = 12 weeks, how much would be owed?
#
# For the payday loan problem, what is the effective annual interest rate? Don't be shocked — the answer is big.
# Jonny Appleseed invests $10,000 USD in an investment fund. After one year, he receives $1,200 USD annually for 5 years. After 10 years from the initial investment, he receives a lump sum of $15,000 USD. Assuming a minimum attractive rate of return (MARR) of 7%.
#
# Calculate the External Rate of Return (ERR).
# What is the external rate of return for Washington Mill Works if they purchase a resawing band saw for 25000 USD with a useful life of 10 years, a salvage value of 5000 USD, annual income of 15000 USD, and annual operating expenses of 3000 USD, assuming a minimum attractive rate of return (MARR) of 8%.
#
# External Rate of Return =
# An injection molding press is purchased for 15,000 USD. It is agreed that the press will be paid for over a 5 year period with annual payments using a 7% annual compound interest rate. Each payment is to be $200 less than the previous payment.
#
# What is the size of the first payment?
# Washington Mill Works is considering the purchase of a large resawing band saw for 25000 USD. The saw is expected to have a useful life of 10 years, after which it will have an estimated salvage value of $5000. Each year, the annual income is estimated to be 8000, while the annual operating expenses are 3000. Assuming a minimum attractive rate of return (MARR) of 8%:
#
# 1. Calculate the equivalent present worth of the cash flows over the seven-year period.
# 2. Calculate the equivalent annual worth of the cash flows over the seven-year period.
# 3. Calculate the equivalent future worth of the cash flows over the seven-year period.
# 4. Calculate the internal rate of return (IRR).
# Jonny Appleseed invests $10,000 USD in an investment fund. After one year, she receives $1,200 USD annually for 5 years. After 10 years from the initial investment, he receives a lump sum of $15,000 USD. Assuming a minimum attractive rate of return (MARR) of 5%.
#
# 1. Calculate the equivalent present worth of these cash flows. Include a cash flow diagram in your solution.
#
# 2. Calculate the Internal Rate of Return (IRR).
# A company would like to pick the best option out of the three described in the table below. The table shows the net cash flow for each year of the 10-year planning horizon. MARR is 10%.
#
# | Year (EOY) | Option 0 | Option 1 | Option 2 |
# |------------|-----------|-----------|-----------|
# | 0          | 0         | {{params.cost1}} | {{params.cost2}} |
# | 1          | 0         | {{params.A1}} | {{params.A21}} |
# | 2          | 0         | {{params.A1}} | {{params.A22}} |
# | 3          | 0         | {{params.A1}} | {{params.A23}} |
# | 4          | 0         | {{params.A1}} | {{params.A24}} |
# | 5          | 0         | {{params.A1}} | {{params.A25}} |
#
# **Tasks:**
# 1. Compute the present worth of option zero.
# 2. Compute the present worth of option one.
# 3. Compute the present worth of option two.
# You take out a 30-year fixed-rate mortgage for a house. The amount borrowed is 300,000 USD. The interest rate is 3.5% per year compounded monthly. You decide to sell the house immediately after the 12th payment.
#
# 1. How much do you still owe on the loan?
# 2. What is the total amount you have paid the lender by the time you sell the house?
# 3. How much principal have you paid the lender by the time you sell the house?
# 4. How much interest have you paid the lender by the time you sell the house?
# Juan takes out a $250,000 USD 30-year fixed rate mortgage to purchase a home. The interest rate is 5% per year compounded monthly.
#
# Calculate the month in which the interest portion of the payment is less than one third of the total monthly payment.
# The national debt is 31 trillion dollars. The total tax revenue collected by the US government from individual income tax returns was 5 trillion dollars. Assume that the interest on the debt is 3% and that the annual revenue from individual income tax returns remains constant.
#
# Determine **n**, the number of years it would take to pay off the current national debt if all of the tax revenue from personal income tax returns were applied to the debt each year.
#
# Assuming that all revenue from personal income tax returns were applied to the debt, what is the smallest interest rate for which the debt will never be paid off?
# Alice Smith invests $10,000 USD in an investment fund. After one year, she receives $1,200 USD annually for 5 years. After 10 years from the initial investment, she receives a lump sum of $15,000 USD. Assuming a minimum attractive rate of return (MARR) of 5%, calculate the equivalent present worth of these cash flows. Include a cash flow diagram in your solution.
# Washington Mill Works is considering the purchase of a large resawing band saw for 50,000 USD. The saw is expected to have a useful life of 10 years, after which it will have an estimated salvage value of $5,000. Each year, the annual income is estimated to be 20,000 USD, while the annual operating expenses are 8,000 USD. Assuming a minimum attractive rate of return (MARR) of 10%, calculate the equivalent present worth of the cash flows over the seven-year period.
# A sum of ${{params.principal}} is borrowed at an interest rate of {{params.interestRate}}% per year.
#
# **Calculations:**
# 1. Calculate the amount owed after 1 year if the interest is compounded monthly.
#    - Amount owed (Monthly Compounding) =
#
# 2. Calculate the amount owed after 1 year if the interest is compounded weekly.
#    - Amount owed (Weekly Compounding) =
#
# 3. Calculate the amount owed after 1 year if the interest is compounded daily.
#    - Amount owed (Daily Compounding) =
# How long will it take for Sam Bigscreen to pay off his credit card debt of 5000 USD, with an interest rate of 15% per year compounded monthly, if he pays a minimum payment of 200 USD per month?
#
# 1. What is the time (in months) to pay off the debt?
# 2. How much interest will he pay?
# 3. What is the largest monthly payment for which Sam Bigscreen will never pay off the debt?
# You would like to purchase a house. You plan to make a down payment equal to 20% of the purchase price and take out a 30-year, fixed-rate mortgage for the remaining 80%. You would like to select a house such that your monthly payment, including mortgage and taxes, does not exceed 2000 USD. The annual tax rate is 1.25% of the purchase price and there is a special assessment for the local school district of 500 USD per year. You can assume that 1/12th of the tax and assessment is paid each month. If the interest rate is 4%/year compounded monthly, what is the most expensive house you can afford?
# A loan of 15000 USD is to be paid off in 5 equal annual payments. The interest rate is 5% per year compounded annually. If the first payment is made at the end of Year 1, what is the annual payment?
# A 30-year mortgage has an interest rate of 3.5% per year compounded monthly. The initial principal is 250,000 USD.
#
# Calculate the monthly payment and the total interest paid over the life of the mortgage.
# A loan of 5000 USD is to be paid off in 10 equal annual payments. The interest rate is 5% per year compounded annually. If the first payment is made at the end of Year 0, what is the annual payment?
# How much should be deposited at \( t = 0 \) into a fund paying 5\% compounded per period in order to withdraw 100$ at \( t = 1 \), 150$ at \( t = 2 \), and 200$ at \( t = 3 \) such that the fund is depleted at the last withdrawal?
# How much can Taylor withdraw each month during retirement if she deposits 500 USD monthly for 30 years into an account that pays 5% per year compounded monthly, and then after the last deposit, the interest rate increases to 6% per year compounded monthly? The withdrawals will occur monthly for 20 years.
#
# What is the monthly withdrawal amount (in USD)?
# A specialized autoclave for curing carbon fiber airplane parts is purchased for 100,000 USD in 2024. The autoclave is depreciated using the appropriate MACRS schedule, which follows a 7-year deduction period. The tax rate is 30%.
#
# The autoclave is sold during year 10 for a salvage value of 15,000 USD. How much tax is paid on the salvage at EOY 10?
#
# **Tax paid in EOY 10:**
#
# The autoclave is sold during year 10 for a salvage value of 15,000 USD. How much tax is paid on the salvage at EOY 10?
#
# **Tax paid in EOY 10:**
#
# The autoclave is sold during year 10 for a salvage value of 10,000 USD. How much tax is paid on the salvage at EOY 10?
#
# **Tax paid in EOY 10:**
# Given the following cash flow details for the year 2018:
#
# - Before-Tax-and-Loan Cash Flow = 100,000
# - Payment on loan principal = 10,000
# - Payment on loan interest = 5,000
# - MACRS Depreciation Deduction = 15,000
# - Tax Rate = 30%
#
# 1. What is the taxable income for ACME Inc?
# 2. What is the tax paid?
# 3. What is the after-tax cash flow (ATCF)?
# A machine specialized for use in the manufacture of motor vehicles is purchased for 50,000 USD. The machine is purchased with a 30,000 USD loan and 20,000 USD of equity.
#
# The loan has an interest rate of 5% and is paid off in five years. The machine is depreciated using the MACRS 3-year schedule. The revenue minus cost for each of the five years of operation is 15,000 USD. The tax rate is 30%. Complete the table below.
#
# \[
#     \small % Reduce font size for the table
#     \begin{array}{|c|c|c|c|c|c|c|c|c|c|}
#     \hline
#     \textbf{EOY} & \textbf{BTLCF} & \textbf{MACRS Deduction} & \textbf{Book Value} & \textbf{Loan Principal Payment} & \textbf{Loan Interest Payment} & \textbf{Remaining Principal} & \textbf{Taxable Income} & \textbf{Tax} & \textbf{ATCF} \\
#     \hline
#     0 & & & & & & & & & \\ \hline
#     1 & & & & & & & & & \\ \hline
#     2 & & & & & & & & & \\ \hline
#     3 & & & & & & & & & \\ \hline
#     4 & & & & & & & & & \\ \hline
#     5 & & & & & & & & & \\ \hline
#     \end{array}
# \]
#
# **Loan Payments**
# Monthly Loan Payment =
#
# **EOY 1**
# Interest Paid at EOY1 =
# Remaining Principal at EOY1 =
# Taxable Income at EOY 1 =
# After Tax Cash Flow (AFCF) at EOY 1 =
#
# **EOY 3**
# Interest Paid at EOY3 =
# Remaining Principal at EOY3 =
# Taxable Income at EOY 3 =
# After Tax Cash Flow (AFCF) at EOY 3 =
#
# **EOY 5**
# Interest Paid at EOY5 =
# Remaining Principal at EOY5 =
# Taxable Income at EOY 5 =
# After Tax Cash Flow (AFCF) at EOY 5 =
#
# ['{\n    "custom_id": "ddSwitchToSL",\n    "method": "POST",\n    "url": "/v1/embeddings",\n    "body": {\n        "model": "text-embedding-3-small",\n        "input": "Create a table showing the depreciation and book value for each year (i.e., from EOY 0 through EOY 10) for a milling machine purchased for 20000 USD with a salvage value of 2000 USD and a useful life of 10 years using double declining balance depreciation and switching to straight-line depreciation.\\n\\nWhat is the book value at EOY 1, EOY 5, and EOY 10?\\n\\n- Book Value at EOY 1 = \\n- Book Value at EOY 5 = \\n- Book Value at EOY 10 = "\n    }\n}', '{\n    "custom_id": "doubleDecline",\n    "method": "POST",\n    "url": "/v1/embeddings",\n    "body": {\n        "model": "text-embedding-3-small",\n        "input": "Create a table showing the depreciation and book value for each year (i.e., from EOY 0 through EOY 10) for a milling machine purchased for 50000 USD with a salvage value of 5000 USD and a useful life of 10 years using double declining balance depreciation.\\n\\nWhat is the book value at EOY 1, EOY 5, and EOY 10?\\n\\n- Book Value at EOY 1 = 45000\\n- Book Value at EOY 5 = 25000\\n- Book Value at EOY 10 = 5000"\n    }\n}', '{\n    "custom_id": "MARCSDeduction5year",\n    "method": "POST",\n    "url": "/v1/embeddings",\n    "body": {\n        "model": "text-embedding-3-small",\n        "input": "Using the MACRS deduction method for a large tape-drive system purchased for 50,000 USD classified as 5-year property, calculate the depreciation expense and the book value of the system at the end of each year for its 7-year useful life.\\n\\nCalculate the following:\\n- Book Value at End of Year 1 \\n- Book Value at End of Year 2 \\n- Book Value at End of Year 3 \\n- Book Value at End of Year 4 \\n- Book Value at End of Year 5 \\n- Book Value at End of Year 6 \\n- Book Value at End of Year 7."\n    }\n}', '{\n    "custom_id": "MARCSDeduction7year",\n    "method": "POST",\n    "url": "/v1/embeddings",\n    "body": {\n        "model": "text-embedding-3-small",\n        "input": "Using the MACRS deduction method for a large tape-drive system purchased for {{params.cost}} USD, classified as {{params.propertyClass}}-year property, calculate the depreciation expense and the book value of the system at the end of each year for its {{params.usefulLife}}-year useful life.\\n\\n### Book Value Calculations:\\n- **Book Value at End of Year 1:**  {{bookValueEndYear1}}\\n- **Book Value at End of Year 2:**  {{bookValueEndYear2}}\\n- **Book Value at End of Year 3:**  {{bookValueEndYear3}}\\n- **Book Value at End of Year 4:**  {{bookValueEndYear4}}\\n- **Book Value at End of Year 5:**  {{bookValueEndYear5}}\\n- **Book Value at End of Year 6:**  {{bookValueEndYear6}}\\n- **Book Value at End of Year {{params.endend}}:**  {{bookValueEndYearendend}}\\n- **Book Value at End of Year {{params.end}}:**  {{bookValueEndYearend}}"\n    }\n}', '{\n    "custom_id": "straightLineMethod",\n    "method": "POST",\n    "url": "/v1/embeddings",\n    "body": {\n        "model": "text-embedding-3-small",\n        "input": "A milling machine is purchased for 15,000 USD at EOY 0. The machine is expected to have a 10-year life and a salvage value of 2,000 USD.\\n\\nCreate a table showing the depreciation and book value for each year (i.e., from EOY 0 through EOY 10) using straight-line depreciation. What is the book value at EOY 5 and EOY 10?"\n    }\n}', '{\n    "custom_id": "AmountOfPayments",\n    "method": "POST",\n    "url": "/v1/embeddings",\n    "body": {\n        "model": "text-embedding-3-small",\n        "input": "You purchase a home with a 3%/year fixed-rate, 30-year mortgage. Interest is compounded monthly. The amount borrowed is $250,000. Every 3 months, you make an additional quarter payment which is used to pay off principal (e.g., at EOM 1 payment = A, at EOM 2 payment = A, at EOM 3 payment = 1.25A).\\n\\nCalculate how many months it will take to pay off the mortgage considering bo ...

# %%
batch_input_file = client.files.create(
    file=open(os.path.join(os.getcwd(),"175batch_embedding.jsonl"), "rb"),
    purpose="batch"
)
print(batch_input_file)
batch_input_file_id = batch_input_file.id
client.batches.create(
    input_file_id=batch_input_file_id,
    endpoint="/v1/embeddings",
    completion_window="24h",
    metadata={
        "description": "update"
    }
)
# Out:
# FileObject(id='file-XV1v4URA1APA3ThLnPzE3j', bytes=19221, created_at=1735586471, filename='175batch_embedding.jsonl', object='file', purpose='batch', status='processed', status_details=None)
# Batch(id='batch_6772f2a8e16c81909a0ce6281f5e570d', completion_window='24h', created_at=1735586473, endpoint='/v1/embeddings', input_file_id='file-XV1v4URA1APA3ThLnPzE3j', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1735672873, failed_at=None, finalizing_at=None, in_progress_at=None, metadata={'description': 'update'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))

# %%
batch = client.batches.retrieve("batch_6772f2a8e16c81909a0ce6281f5e570d")
print(batch)
# Out:
# Batch(id='batch_6772f2a8e16c81909a0ce6281f5e570d', completion_window='24h', created_at=1735586473, endpoint='/v1/embeddings', input_file_id='file-XV1v4URA1APA3ThLnPzE3j', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1735586488, error_file_id=None, errors=None, expired_at=None, expires_at=1735672873, failed_at=None, finalizing_at=1735586483, in_progress_at=1735586474, metadata={'description': 'update'}, output_file_id='file-RDNyEUmi2dr5a7T8fiepxD', request_counts=BatchRequestCounts(completed=33, failed=0, total=33))

# %%
file_response = client.files.content("file-RDNyEUmi2dr5a7T8fiepxD")
file_response.text
# Out:
# '{"id": "batch_req_6772f2b364108190b9c8fd32a4d78794", "custom_id": "ddSwitchToSL", "response": {"status_code": 200, "request_id": "be3bbc62a68b3e7daede8cf7ce602fb6", "body": {"object": "list", "data": [{"object": "embedding", "index": 0, "embedding": [0.008822514, 0.06810361, 0.059388254, 0.0036820003, 0.016382966, 0.0030197166, 0.0067329705, 0.02826538, 0.03393274, -0.026884258, 0.082152955, -0.02728907, -0.05300652, -0.046053283, 0.04498172, 0.017394995, -0.04136223, 0.002664018, 0.019764334, 0.027170008, 0.017037809, 0.028503506, -0.009292809, -0.022324173, 0.020562053, -3.7648788e-05, 0.03981442, -0.011810976, 0.01656156, -0.031027624, -0.014180315, -0.0094654495, -0.018573713, 0.02631276, -0.015918624, -0.021276426, 0.022455143, 0.0005633133, -0.0074592503, -0.0050899116, 0.0066496274, -0.041719414, 0.030765688, 0.053768516, 0.020454897, 0.022467049, 0.008030749, -0.079438336, 0.036266364, 0.010263166, 0.017549777, -0.014430346, 0.037861798, 8.8878114e-05, -0.009649996, 0.015620968, -0.014537502, -0.019776242, 0.0034528056, -0.02640801, 0.0065960493, -0.015251875, 0.04000492, -0.034742367, 0.00048257422, 0.004074906, -0.024598263, 0.075342596, -0.031646747, -0.038314234, -0.034242306, 0.009358293, 0.02574126, -0.027527194, 0.012477725, -0.0307895, 2.4736812e-06, -0.0050214506, -0.009876214, -0.056673635, 0.008679639, -0.0009130587, -0.01359691, 0.038599983, -0.012656318, -0.0430291, 0.00012966624, -0.014204128, -0.026789008, -0.011590711, -0.015847187, 0.040862165, 0.024479201, -0.008542717, 0.051815894, -0.04543416, -0.015704311, -0.0016147819, -0.0319325, -0.049577523, -0.015251875, 0.03274212, 0.022848047, -0.002744385, 0.008179577, 0.053054143, -0.013632628, -0.024622075, -0.04805353, -0.020633489, -0.055340137, -0.0056137857, 0.012834911, 0.01350166, -0.007066345, 0.0047208187, -0.11344252, 0.0013312649, 0.0095130745, -0.08362933, -0.022157487, 0.032956433, -0.019490492, -0.079057336, -0.005295294, 0.0077271406, -0.028313005, -0.015525718, 0.008441514, -0.04352916, -0.00038285958, -0.0017710511, 0.013620722, -0.06781786, -0.018323682, -0.0061019408, -0.016573466, 0.05138727, 0.021157363, 0.026241321, -0.015573343, 0.014216034, 0.020109616, -0.019228555, -0.05905488, 0.0370998, 0.049387023, -0.0011563922, -0.0026000221, -0.035385303, -0.00026063473, -0.03419468, 0.0029333965, -0.00684608, 0.06167425, 0.0014957197, 0.014073159, 0.019228555, -0.0062448154, 0.008125999, 0.008417701, -0.020800177, 0.01766884, 0.024836387, -0.002396128, 0.04029067, -0.06415074, 0.005798332, -0.051625393, 0.007875969, 0.017073527, -0.0023559444, 0.0185499, -0.05867388, 0.029646503, 0.02000246, -0.009263043, -0.05672126, 0.010656072, -0.01996674, -0.028003443, -0.010316744, -0.03428993, 0.0043606553, -0.022621829, -0.04786303, -0.00908445, 0.010298885, 0.003845711, 0.011215664, -0.0018663009, 0.0034438758, -0.0094714025, 0.018859461, 0.009149934, -0.0012620599, -0.012846817, 0.0055929497, 0.036766425, -0.014204128, -0.0051762317, 0.019752428, 0.010048854, 0.018966617, -0.011019212, 0.037147425, -0.042814787, 0.048029713, 0.010953728, 0.038052298, 0.02403867, 0.032599248, -0.004167179, 0.038028486, -0.014477971, -0.012596787, -0.0038129687, 0.0024839363, 0.031742, 0.035004303, 0.017442621, 0.04738678, 0.054149516, 0.039838232, 0.026622321, -0.013442129, 0.055483013, -0.0024973308, 0.032313496, -0.07462823, 0.020478709, -0.020276302, 0.0060215737, -0.003577821, -0.023360016, 0.045791343, -0.012918255, -0.016692529, -0.020038178, 0.058197632, -0.02015724, 0.026836634, -0.050577648, 0.02700332, -0.025574572, 0.020871613, -0.010763228, -0.010906103, 0.0063638776, 0.026836634, -0.03167056, -0.011162086, 0.05091102, 0.0065662838, -0.014025534, -0.0067805955, -0.05281602, -0.010858478, -0.0033188604, -0.027622445, -0.0043874444, -0.050387148, -0.031027624, 0.045696095, -0.035099555, 0.06557949, -0.0037832032, -0.021966986, -0.020085802, -9.655205e-05, 0.002181816, 0.022931391, -0.015144719, -0.00058377715, -0.012132444, -0.07315185, -0.029194066, 0. ...

# %%
data = {}
for line in file_response.text.split('\n'):
    line = line.strip()
    if line:  
        try:
            content = json.loads(line)
            question_id = content["custom_id"]
            embedding = content["response"]["body"]['data'][0]['embedding']
            data[question_id] = str(embedding) # Conver to string reminder to need to convert back 
            # print(embedding)
        except json.JSONDecodeError as e:
            print(f"Skipping invalid JSON line: {line} | Error: {e}")
df_batch_embedding = pd.DataFrame.from_dict(data, orient='index')

# %%
df_batch_embedding.head()
# Out:
#                                                                      0
# ddSwitchToSL         [0.008822514, 0.06810361, 0.059388254, 0.00368...
# doubleDecline        [0.017977716, 0.06909924, 0.05670903, 0.004378...
# MARCSDeduction5year  [0.0074357996, 0.046291497, 0.0006788812, -0.0...
# MARCSDeduction7year  [0.018601537, 0.04095613, 0.004502403, -0.0155...
# straightLineMethod   [0.0019877013, 0.0844819, 0.026290337, 0.01974...

# %%
final_df =pd.merge(new_df, df_batch_embedding, left_index=True, right_index=True)
final_df.rename(columns={0: 'embeddings-3-small'}, inplace=True)
final_df.head()
# Out:
#                                                              info.json  \
# ddSwitchToSL         {\n    "title": "DoubleDecliningBalanceDepreci...
# doubleDecline        {\n    "title": "DoubleDecliningBalanceDepreci...
# MARCSDeduction5year  {\n    "title": "MacrsDepreciationCalculation"...
# MARCSDeduction7year  {\n    "title": "MacrsDepreciationCalculation"...
# straightLineMethod   {\n    "title": "MillingMachineDepreciation",\...
#
#                                                          question.html  \
# ddSwitchToSL         <pl-question-panel>\n    <p>Create a table sho...
# doubleDecline        <pl-question-panel>\n    <p>Create a table sho...
# MARCSDeduction5year  <pl-question-panel>\n    <p>Using the MACRS de...
# MARCSDeduction7year  <pl-question-panel>\n    <p>Using the MACRS de...
# straightLineMethod   <pl-question-panel>\n    <p>A milling machine ...
#
#                                                              server.js  \
# ddSwitchToSL         const math = require('mathjs'); \n\nconst gene...
# doubleDecline        const math = require('mathjs');\n//const { bve...
# MARCSDeduction5year  const math = require('mathjs');\n\nconst MACRS...
# MARCSDeduction7year  const math = require('mathjs');\n\nconst MACRS...
# straightLineMethod   const math = require('mathjs');\n\nconst gener...
#
#                                                          solution.html  \
# ddSwitchToSL         <pl-solution-panel>\n   \n        <pl-hint lev...
# doubleDecline        <pl-solution-panel>\n    <pl-hint level="1" da...
# MARCSDeduction5year  <pl-solution-panel>\n    <pl-hint level="1" da...
# MARCSDeduction7year  <pl-solution-panel>\n    <pl-hint level="1" da...
# straightLineMethod   <pl-solution-panel>\n    <pl-hint level="1" da...
#
#                                                               question  \
# ddSwitchToSL         Create a table showing the depreciation and bo...
# doubleDecline        Create a table showing the depreciation and bo...
# MARCSDeduction5year  Using the MACRS deduction method for a large t...
# MARCSDeduction7year  Using the MACRS deduction method for a large t...
# straightLineMethod   A milling machine is purchased for 15,000 USD ...
#
#                                                     embeddings-3-small
# ddSwitchToSL         [0.008822514, 0.06810361, 0.059388254, 0.00368...
# doubleDecline        [0.017977716, 0.06909924, 0.05670903, 0.004378...
# MARCSDeduction5year  [0.0074357996, 0.046291497, 0.0006788812, -0.0...
# MARCSDeduction7year  [0.018601537, 0.04095613, 0.004502403, -0.0155...
# straightLineMethod   [0.0019877013, 0.0844819, 0.026290337, 0.01974...

# %% [markdown]
# ## Final Combine with existing dataset

# %%
old_path = os.path.abspath(os.path.join(os.getcwd(), '..','..'))+ r'\src\data\question_embeddings_2024_9_11.csv'
old_df = pd.read_csv(old_path)
print(old_df.columns)
old_df = old_df.drop(columns =['Unnamed: 0.2','Unnamed: 0.1'])
old_df.head()
old_df.tail()
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Question Title', 'Unnamed: 0',
#        'question.html', 'server.js', 'solution.html', 'server.py',
#        'properties.js', 'info1.json', 'server_trap.js', 'server1.py',
#        'server2.py', 'test1.py', 'server3.py', '.DS_Store', 'question',
#        'question_embedding', 'uuid', 'title', 'stem', 'topic', 'tags',
#        'prereqs', 'isAdaptive', 'createdBy', 'qType', 'nSteps', 'updatedBy',
#        'difficulty', 'codelang', 'resources', 'stepType', 'dificulty',
#        'embeddings-3-small'],
#       dtype='object')
#     Question Title  Unnamed: 0  \
# 282            NaN         NaN
# 283            NaN         NaN
# 284            NaN         NaN
# 285            NaN         NaN
# 286            NaN         NaN
#
#                                          question.html server.js  \
# 282  <div class="card my-2">\r\n    <div class="car...       NaN
# 283  <pl-question-panel>\r\n    <p>\r\n        Ques...       NaN
# 284  \r\n<pl-question-panel>\r\n\r\n<p>The element ...       NaN
# 285  <pl-card header="Header" title="Title" subtitl...       NaN
# 286                                                NaN       NaN
#
#     solution.html                                          server.py  \
# 282           NaN  import prairielearn as pl\r\nimport sympy\r\n\...
# 283           NaN  import prairielearn as pl\r\n\r\n\r\ndef gener...
# 284           NaN  import numpy as np\r\nimport prairielearn as p...
# 285           NaN  import numpy as np\r\nimport prairielearn as p...
# 286           NaN                                                NaN
#
#     properties.js info1.json server_trap.js server1.py  ... createdBy qType  \
# 282           NaN        NaN            NaN        NaN  ...       NaN   NaN
# 283           NaN        NaN            NaN        NaN  ...       NaN   NaN
# 284           NaN        NaN            NaN        NaN  ...       NaN   NaN
# 285           NaN        NaN            NaN        NaN  ...       NaN   NaN
# 286           NaN        NaN            NaN        NaN  ...       NaN   NaN
#
#     nSteps  updatedBy difficulty codelang resources stepType dificulty  \
# 282    NaN        NaN        NaN      NaN       NaN      NaN       NaN
# 283    NaN        NaN        NaN      NaN       NaN      NaN       NaN
# 284    NaN        NaN        NaN      NaN       NaN      NaN       NaN
# 285    NaN        NaN        NaN      NaN       NaN      NaN       NaN
# 286    NaN        NaN        NaN      NaN       NaN      NaN       NaN
#
#                                     embeddings-3-small
# 282  [0.036735910922288895, -0.005829245317727327, ...
# 283  [0.012048509903252125, 0.027021152898669243, 0...
# 284  [0.024972645565867424, 0.013344255276024342, 0...
# 285  [-0.015040713362395763, 0.010234958492219448, ...
# 286  [0.01346839964389801, -0.0219414085149765, 0.0...
#
# [5 rows x 33 columns]

# %%
# final_df = final_df.reset_index()
# final_df.rename(columns={'index': 'Question Title'}, inplace=True)
print(final_df.shape)
print(old_df.shape)
# Out:
# (33, 7)
# (287, 33)

# %%
# Perform the first merge
df_new_data = pd.merge(old_df, final_df, left_index=True, right_index=True)

# Define overlap columns
overlap_columns = ['question.html', 'server.js', 'solution.html', 'question', 'embeddings-3-small', 'Question Title']

# Merge on overlap columns
merged_df = pd.merge(old_df, final_df, on=overlap_columns, how='outer', indicator=True)

# Handle duplicates in 'Question Title'
if 'Question Title' in merged_df.columns:
    merged_df['Question Title'] = merged_df['Question Title'].astype(str)  # Ensure values are strings
    merged_df['Question Title'] = merged_df.groupby('Question Title').cumcount().apply(
        lambda x: f"{x}" if x > 0 else ""
    ).radd(merged_df['Question Title'])

# Print the resulting DataFrame
merged_df.head()
merged_df.sort_values(by='Question Title', ascending=True, inplace=True)

# %%
df_new_data
# Out:
#       Question Title_x  Unnamed: 0  \
# 0            3dMoment1         0.0
# 1            3dMoment2         1.0
# 2            3dMoment3         2.0
# 3            3dMoment4         3.0
# 4         Equilibrium1         4.0
# 5         Equilibrium2         5.0
# 6         Equilibrium3         6.0
# 7         Equilibrium4         7.0
# 8               Frame1         8.0
# 9               Frame3         9.0
# 10            Squeezer        10.0
# 11  distributedForces1        11.0
# 12  distributedForces2        12.0
# 13  distributedForces3        13.0
# 14  distributedForces4        14.0
# 15  distributedForces5        15.0
# 16   FramesAndMachines        16.0
# 17             joints1        17.0
# 18             joints2        18.0
# 19       myForceVector        19.0
# 20            myMoment        20.0
# 21       reactionForce        21.0
# 22             sqeezer        22.0
# 23        RigidBodies1        23.0
# 24        RigidBodies2        24.0
# 25        RigidBodies3        25.0
# 26        RigidBodies4        26.0
# 27        RigidBodies5        27.0
# 28              truss1        28.0
# 29              truss2        29.0
# 30           3DMoment1        30.0
# 31           3DMoment2        31.0
# 32           3DMoment3        32.0
#
#                                       question.html_x  \
# 0   <pl-question-panel>\r\n    <pl-figure file-nam...
# 1   <pl-question-panel>\r\n    <pl-figure file-nam...
# 2   <pl-question-panel>\r\n    <pl-figure file-nam...
# 3   <pl-question-panel>\r\n    <pl-figure file-nam...
# 4   <pl-question-panel>\r\n<pl-figure file-name="3...
# 5   <pl-question-panel>\r\n    <pl-figure file-nam...
# 6   <pl-question-panel>\r\n    <pl-figure file-nam...
# 7   <pl-question-panel>\r\n    <pl-figure file-nam...
# 8   <pl-question-panel>\r\n    <pl-figure file-nam...
# 9   \r\n\r\n\r\n<pl-question-panel>\r\n    <pl-fig...
# 10  <pl-question-panel>\r\n    <pl-figure file-nam...
# 11  <pl-question-panel>\r\n    <pl-figure file-nam...
# 12  <pl-question-panel>\r\n    <pl-figure file-nam...
# 13  <pl-question-panel>\r\n    <pl-figure file-nam...
# 14  <pl-question-panel>\r\n    <pl-figure file-nam...
# 15  <pl-question-panel>\r\n    <pl-figure file-nam...
# 16  \r\n\r\n\r\n<pl-question-panel>\r\n    <pl-fig...
# 17  <pl-question-panel>\r\n    <pl-figure file-nam...
# 18  <pl-question-panel>\r\n    <pl-figure file-nam...
# 19  <pl-question-panel>\r\nA force of magnitude {{...
# 20  \r\n<pl-question-panel>\r\n    <pl-figure file...
# 21  <pl-question-panel>\r\n    <pl-figure file-nam...
# 22  <pl-question-panel>\r\n    <pl-figure file-nam...
# 23  <pl-question-panel>\r\n    <pl-figure file-nam...
# 24  <pl-question-panel>\r\n<pl-figure file-name="3...
# 25  <pl-question-panel>\r\n    <pl-figure file-nam...
# 26  <pl-question-panel>\r\n    <pl-figure file-nam...
# 27  <pl-question-panel>\r\n    <pl-figure file-nam...
# 28  <pl-question-panel>\r\n    <pl-figure file-nam...
# 29  <pl-question-panel>\r\n    <pl-figure file-nam...
# 30  <pl-question-panel>\r\n  <pl-figure file-name=...
# 31  <pl-question-panel>\r\n  <pl-figure file-name=...
# 32  <pl-question-panel>\r\n  <pl-figure file-name=...
#
#                                           server.js_x  \
# 0   const math = require('mathjs');\r\n// const ma...
# 1   const math = require('mathjs');\r\n// const ma...
# 2   const math = require('mathjs');\r\n// const ma...
# 3   const math = require('mathjs');\r\n// const ma...
# 4   const math = require('mathjs');\r\n// const ma...
# 5   const math = require('mathjs');\r\n// const ma...
# 6   const math = require('mathjs');\r\n// const ma...
# 7   const math = require('mathjs');\r\n// const ma...
# 8   const math = require('mathjs');\r\n// const ma...
# 9   const math = require('mathjs');\r\n// const ma...
# 10  const math = require('mathjs');\r\n// const ma...
# 11  const math = require('mathjs');\r\n// const ma...
# 12  const math = require('mathjs');\r\n// const ma...
# 13  const math = require('mathjs');\r\n// const ma...
# 14  const math = require('mathjs');\r\n// const ma...
# 15  const math = require('mathjs');\r\n// const ma...
# 16  const math = require('mathjs');\r\n// const ma...
# 17  const math = require('mathjs');\r\n// const ma...
# 18  const math = require('mathjs');\r\n// const ma...
# 19  //const { data } = require('cheerio/lib/api/at...
# 20  const math = require('mathjs');\r\n// const ma...
# 21  const math = require('mathjs');\r\n// const ma...
# 22  const math = require('mathjs');\r\n// const ma...
# 23  const math = require('mathjs');\r\n// const ma...
# 24  const math = require('mathjs');\r\n// const ma...
# 25  const math = require('mathjs');\r\n// const ma...
# 26  const math = require('mathjs');\r\n// const ma...
# 27  const math = require('mathjs');\r\n// const ma...
# 28  const math = require('mathjs');\r\n// const ma...
# 29  const math = require('mathjs');\r\n// const ma...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
#
#                                       solution.html_x server.py properties.js  \
# 0   <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 1   <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 2   <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 3   <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 4   <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 5   <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 6   <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 7   <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 8   <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 9   <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 10  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 11  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 12  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 13  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 14  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 15  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 16  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 17                                                NaN       NaN           NaN
# 18                                                NaN       NaN           NaN
# 19                                                NaN       NaN           NaN
# 20                                                NaN       NaN           NaN
# 21                                                NaN       NaN           NaN
# 22                                                NaN       NaN           NaN
# 23  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 24  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 25  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 26  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 27  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 28                                                NaN       NaN           NaN
# 29                                                NaN       NaN           NaN
# 30  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 31  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
# 32  <pl-solution-panel>\r\n    <pl-figure file-nam...       NaN           NaN
#
#    info1.json server_trap.js server1.py  ... stepType dificulty  \
# 0         NaN            NaN        NaN  ...      NaN       NaN
# 1         NaN            NaN        NaN  ...      NaN       NaN
# 2         NaN            NaN        NaN  ...      NaN       NaN
# 3         NaN            NaN        NaN  ...      NaN       NaN
# 4         NaN            NaN        NaN  ...      NaN       NaN
# 5         NaN            NaN        NaN  ...      NaN       NaN
# 6         NaN            NaN        NaN  ...      NaN       NaN
# 7         NaN            NaN        NaN  ...      NaN       NaN
# 8         NaN            NaN        NaN  ...      NaN       NaN
# 9         NaN            NaN        NaN  ...      NaN       NaN
# 10        NaN            NaN        NaN  ...      NaN       NaN
# 11        NaN            NaN        NaN  ...      NaN       NaN
# 12        NaN            NaN        NaN  ...      NaN       NaN
# 13        NaN            NaN        NaN  ...      NaN       NaN
# 14        NaN            NaN        NaN  ...      NaN       NaN
# 15        NaN            NaN        NaN  ...      NaN       NaN
# 16        NaN            NaN        NaN  ...      NaN       NaN
# 17        NaN            NaN        NaN  ...      NaN       NaN
# 18        NaN            NaN        NaN  ...      NaN       NaN
# 19        NaN            NaN        NaN  ...      NaN       NaN
# 20        NaN            NaN        NaN  ...      NaN       NaN
# 21        NaN            NaN        NaN  ...      NaN       NaN
# 22        NaN            NaN        NaN  ...      NaN       NaN
# 23        NaN            NaN        NaN  ...      NaN       NaN
# 24        NaN            NaN        NaN  ...      NaN       NaN
# 25        NaN            NaN        NaN  ...      NaN       NaN
# 26        NaN            NaN        NaN  ...      NaN       NaN
# 27        NaN            NaN        NaN  ...      NaN       NaN
# 28        NaN            NaN        NaN  ...      NaN       NaN
# 29        NaN            NaN        NaN  ...      NaN       NaN
# 30        NaN            NaN        NaN  ...      NaN       NaN
# 31        NaN            NaN        NaN  ...      NaN       NaN
# 32        NaN            NaN        NaN  ...      NaN       NaN
#
#                                  embeddings-3-small_x  \
# 0   [0.021389668807387352, 0.0019783112220466137, ...
# 1   [-0.0008305445080623031, 0.021679654717445374,...
# 2   [0.01982959173619747, 0.02235875464975834, 0.0...
# 3   [0.011207695119082928, 0.018756229430437088, 0...
# 4   [0.015392015688121319, 0.010134758427739143, 0...
# 5   [0.04372689500451088, -0.053088847547769547, 0...
# 6   [0.06704465299844742, -0.04970955848693848, -0...
# 7   [0.03697505220770836, -0.021439723670482635, 0...
# 8   [0.03559532016515732, 0.03461657837033272, 0.0...
# 9   [0.04400460049510002, -0.01800517551600933, 0....
# 10  [0.00733108539134264, 0.012929847463965416, -0...
# 11  [0.03195083141326904, -0.03883180767297745, 0....
# 12  [0.023015951737761497, -0.02899259887635708, 0...
# 13  [0.026526883244514465, -0.04596448689699173, 0...
# 14  [0.029193919152021408, -0.015812359750270844, ...
# 15  [0.04371020942926407, -0.021640218794345856, 0...
# 16  [0.040583815425634384, -0.015587929636240005, ...
# 17  [0.013836616650223732, 0.011549838818609715, 0...
# 18  [0.002268342301249504, 0.020782874897122383, 0...
# 19  [-0.021962741389870644, 0.006013022735714912, ...
# 20  [0.003889981657266617, 0.004328614566475153, 0...
# 21  [0.02190631628036499, 0.030562343075871468, -0...
# 22  [0.005389475729316473, 0.007777468767017126, -...
# 23  [0.028960533440113068, 0.021821049973368645, -...
# 24  [-0.0014292686246335506, -0.023608971387147903...
# 25  [0.03462011739611626, 0.03794897720217705, 0.0...
# 26  [0.040545541793107986, -0.061887919902801514, ...
# 27  [0.04440224915742874, 0.035338032990694046, 0....
# 28  [0.01935034804046154, -0.007607342675328255, 0...
# 29  [0.004721355624496937, -0.005793536081910133, ...
# 30  [-0.02334902435541153, -0.0003407486656215042,...
# 31  [0.017233634367585182, -0.022736169397830963, ...
# 32  [0.043644580990076065, -0.013504264876246452, ...
#
#            Question Title_y  \
# 0              ddSwitchToSL
# 1             doubleDecline
# 2       MARCSDeduction5year
# 3       MARCSDeduction7year
# 4        straightLineMethod
# 5          AmountOfPayments
# 6               CarPurchase
# 7             FutureSavings
# 8   InterestRateConversions
# 9              IntrestPayed
# 10              loanIntrest
# 11                      ERR
# 12                  ERRcalc
# 13             FirstPayment
# 14   InvestmentLargeBandSaw
# 15                  IRRCalc
# 16                 IRRTable
# 17        EarlyMortgageSell
# 18             MortgageCalc
# 19             NationalDebt
# 20             PresentWorth
# 21         PresentWorthCalc
# 22        CompundedInterest
# 23               CreditCard
# 24             HousePayment
# 25   LoanPaymentCalculation
# 26          MortgagePayment
# 27              PaymentCalc
# 28            PrincipleCalc
# 29        RetirementSavings
# 30                  saleTax
# 31            taxableIncome
# 32                 TaxTable
#
#                                             info.json  \
# 0   {\n    "title": "DoubleDecliningBalanceDepreci...
# 1   {\n    "title": "DoubleDecliningBalanceDepreci...
# 2   {\n    "title": "MacrsDepreciationCalculation"...
# 3   {\n    "title": "MacrsDepreciationCalculation"...
# 4   {\n    "title": "MillingMachineDepreciation",\...
# 5   {\n    "title": "MortgagePaymentCalculation",\...
# 6   {\n    "title": "CarLoanPaymentCalculation",\n...
# 7   {\n    "title": "InvestmentGrowthCalculation",...
# 8   {\n    "title": "InterestRateConversions",\n  ...
# 9   {\n    "title": "MortgageInterestCalculation",...
# 10  {\n    "title": "LoanInterestRateCalculation",...
# 11  {\n    "title": "InvestmentCashFlowAnalysis",\...
# 12  {\n    "title": "ExternalRateOfReturnCalculati...
# 13  {\n    "title": "InjectionMoldingPressPaymentC...
# 14  {\n    "title": "WashingtonMillWorksResawingBa...
# 15  {\n    "title": "InvestmentCashFlowAnalysis",\...
# 16  {\n    "title": "Multi Options",\n    "stem": ...
# 17  {\n    "title": "LoanBalanceCalculation",\n   ...
# 18  {\n    "title": "MortgageInterestCalculation",...
# 19
# 20  {\n    "title": "InvestmentCashFlowAnalysis",\...
# 21  {\n    "title": "WashingtonMillWorksResawingBa...
# 22  {\n    "title": "CompoundingInterestCalculatio...
# 23  {\n    "title": "CreditCardDebtPayoffCalculati...
# 24  {\n    "title": "HouseAffordabilityCalculation...
# 25  {\n    "title": "LoanPaymentCalculation",\n   ...
# 26  {\n    "title": "MortgageCalculation",\n    "s...
# 27  {\n    "title": "LoanPaymentCalculation",\n   ...
# 28  {\n    "title": "FundWithdrawalCalculation",\n...
# 29  {\n    "title": "RetirementWithdrawalCalculati...
# 30  {\n    "title": "AutoclaveTaxLiabilityCalculat...
# 31  {\n    "title": "TaxableIncomeCalculationForAC...
# 32  {\n    "title": "MachinePurchaseFinancialAnaly...
#
#                                       question.html_y  \
# 0   <pl-question-panel>\n    <p>Create a table sho...
# 1   <pl-question-panel>\n    <p>Create a table sho...
# 2   <pl-question-panel>\n    <p>Using the MACRS de...
# 3   <pl-question-panel>\n    <p>Using the MACRS de...
# 4   <pl-question-panel>\n    <p>A milling machine ...
# 5   <pl-question-panel>\n  <p> You purchase a home...
# 6   <pl-question-panel>\n  <p> You are considering...
# 7   <pl-question-panel>\n  <p> If you deposit {{pa...
# 8   <pl-question-panel>\n    <p>\n        A loan h...
# 9   <pl-question-panel>\n  <p> You purchase a home...
# 10  <pl-question-panel>\n  <p>If a loan amount of ...
# 11  <pl-question-panel>\n   \n    <p>Jonny Applese...
# 12  <pl-question-panel>\n    <p>What is the extern...
# 13  <pl-question-panel>\n    <p>An injection moldi...
# 14  <pl-question-panel>\n    <p> Washington Mill W...
# 15  <pl-question-panel>\n   \n    <p>Jonny Applese...
# 16  <pl-question-panel>\n\n    <p>\n        <table...
# 17  <pl-question-panel>\n    \n    <p> You take ou...
# 18  <pl-question-panel>\n    <p> Juan takes out a ...
# 19  <pl-question-panel>\n    <p> The national debt...
# 20  <pl-question-panel>\n    <p>Alice Smith invest...
# 21  <pl-question-panel>\n    <p> Washington Mill W...
# 22  <pl-question-panel>\n    <p> A sum of ${{param...
# 23  <pl-question-panel>\n  <p> How long will it ta...
# 24  <pl-question-panel>\n    <p>You would like to ...
# 25  <pl-question-panel>\n    <p> A loan of {{param...
# 26  <pl-question-panel>\n    <p> A {{params.years}...
# 27  <pl-question-panel>\n    <p> A loan of {{param...
# 28  <pl-question-panel>\n    <p> How much should b...
# 29  <pl-question-panel>\n    <p>How much can Taylo...
# 30  <pl-question-panel>\n  <p>A specialized autocl...
# 31  <pl-question-panel>\n    <p>Given the followin...
# 32  <pl-question-panel>\n    <p>A machine speciali...
#
#                                           server.js_y  \
# 0   const math = require('mathjs'); \n\nconst gene...
# 1   const math = require('mathjs');\n//const { bve...
# 2   const math = require('mathjs');\n\nconst MACRS...
# 3   const math = require('mathjs');\n\nconst MACRS...
# 4   const math = require('mathjs');\n\nconst gener...
# 5   const math = require('mathjs');\n\nconst gener...
# 6   const math = require('mathjs');\n\nconst gener...
# 7   const math = require('mathjs');\n\nconst gener...
# 8   const math = require('mathjs');\n\nconst gener...
# 9   const math = require('mathjs');\n\nconst gener...
# 10  const math = require('mathjs');\n\nconst gener...
# 11  const math = require('mathjs');\n\nconst gener...
# 12  const math = require('mathjs');\n\nconst gener...
# 13  const math = require('mathjs');\n\nconst gener...
# 14  const math = require('mathjs');\n\nconst gener...
# 15  const math = require('mathjs');\n\nconst gener...
# 16  const math = require('mathjs');\n\nconst gener...
# 17  const math = require('mathjs');\n\nconst gener...
# 18  const math = require('mathjs');\n\nconst gener...
# 19  const math = require('mathjs');\n\nconst gener...
# 20  const math = require('mathjs');\n\nconst gener...
# 21  const math = require('mathjs');\n\nconst gener...
# 22  const math = require('mathjs');\n\nconst gener...
# 23  const math = require('mathjs');\n\nconst gener...
# 24  const math = require('mathjs');\n\nconst gener...
# 25  const math = require('mathjs');\n\nconst gener...
# 26  const math = require('mathjs');\n\nconst gener...
# 27  const math = require('mathjs');\n\nconst gener...
# 28  const math = require('mathjs');\n\nconst gener...
# 29  const math = require('mathjs');\n\nconst gener...
# 30  const math = require('mathjs');\n\nconst MACRS...
# 31  const math = require('mathjs');\n\nconst gener...
# 32  const math = require('mathjs');\n\nconst MACRS...
#
#                                       solution.html_y  \
# 0   <pl-solution-panel>\n   \n        <pl-hint lev...
# 1   <pl-solution-panel>\n    <pl-hint level="1" da...
# 2   <pl-solution-panel>\n    <pl-hint level="1" da...
# 3   <pl-solution-panel>\n    <pl-hint level="1" da...
# 4   <pl-solution-panel>\n    <pl-hint level="1" da...
# 5   <pl-solution-panel>\n    <pl-hint level="1" da...
# 6   <pl-solution-panel>\n    <pl-hint level="1" da...
# 7   <pl-solution-panel>\n    <pl-hint level="1" da...
# 8   <pl-solution-panel>\n    <pl-hint level="1" da...
# 9   <pl-solution-panel>\n    <pl-hint level="1" da...
# 10  <pl-solution-panel>\n    <pl-hint level="1" da...
# 11  <pl-solution-panel>\n    <pl-hint level="1" da...
# 12  <pl-solution-panel>\n    <pl-hint level="1" da...
# 13  <pl-solution-panel>\n    <pl-hint level="1" da...
# 14  <pl-solution-panel>\n    <pl-hint level="1" da...
# 15  <pl-solution-panel>\n    <pl-hint level="1" da...
# 16  <pl-solution-panel>\n    <pl-hint level="1" da...
# 17  <pl-solution-panel>\n    <pl-hint level="1" da...
# 18  <pl-solution-panel>\n    <pl-hint level="1" da...
# 19  <pl-solution-panel>\n    <pl-hint level="1" da...
# 20  <pl-solution-panel>\n    <pl-hint level="1" da...
# 21  <pl-solution-panel>\n    <pl-hint level="1" da...
# 22  <pl-solution-panel>\n    <pl-hint level="1" da...
# 23  <pl-solution-panel>\n    <pl-hint level="1" da...
# 24  <pl-solution-panel>\n    <pl-hint level="1" da...
# 25  <pl-solution-panel>\n    <pl-hint level="1" da...
# 26  <pl-solution-panel>\n    <pl-hint level="1" da...
# 27  <pl-solution-panel>\n    <pl-hint level="1" da...
# 28  <pl-solution-panel>\n    <pl-hint level="1" da...
# 29  <pl-solution-panel>\n    <pl-hint level="1" da...
# 30  <pl-solution-panel>\n    <pl-hint level="1" da...
# 31  <pl-solution-panel>\n    <pl-hint level="1" da...
# 32  <pl-solution-panel>\n\n\n    <pl-hint level="0...
#
#                                            question_y  \
# 0   Create a table showing the depreciation and bo...
# 1   Create a table showing the depreciation and bo...
# 2   Using the MACRS deduction method for a large t...
# 3   Using the MACRS deduction method for a large t...
# 4   A milling machine is purchased for 15,000 USD ...
# 5   You purchase a home with a 3%/year fixed-rate,...
# 6   You are considering purchasing a new car from ...
# 7   If you deposit 500 USD every other month into ...
# 8   A loan has a nominal interest rate of 5% per y...
# 9   You purchase a home with a **{{params.interest...
# 10  If a loan amount of 1000 is received at t=0, a...
# 11  Jonny Appleseed invests $10,000 USD in an inve...
# 12  What is the external rate of return for Washin...
# 13  An injection molding press is purchased for 15...
# 14  Washington Mill Works is considering the purch...
# 15  Jonny Appleseed invests $10,000 USD in an inve...
# 16  A company would like to pick the best option o...
# 17  You take out a 30-year fixed-rate mortgage for...
# 18  Juan takes out a $250,000 USD 30-year fixed ra...
# 19  The national debt is 31 trillion dollars. The ...
# 20  Alice Smith invests $10,000 USD in an investme...
# 21  Washington Mill Works is considering the purch...
# 22  A sum of ${{params.principal}} is borrowed at ...
# 23  How long will it take for Sam Bigscreen to pay...
# 24  You would like to purchase a house. You plan t...
# 25  A loan of 15000 USD is to be paid off in 5 equ...
# 26  A 30-year mortgage has an interest rate of 3.5...
# 27  A loan of 5000 USD is to be paid off in 10 equ...
# 28  How much should be deposited at \( t = 0 \) in...
# 29  How much can Taylor withdraw each month during...
# 30  A specialized autoclave for curing carbon fibe...
# 31  Given the following cash flow details for the ...
# 32  A machine specialized for use in the manufactu...
#
#                                  embeddings-3-small_y
# 0   [0.008822514, 0.06810361, 0.059388254, 0.00368...
# 1   [0.017977716, 0.06909924, 0.05670903, 0.004378...
# 2   [0.0074357996, 0.046291497, 0.0006788812, -0.0...
# 3   [0.018601537, 0.04095613, 0.004502403, -0.0155...
# 4   [0.0019877013, 0.0844819, 0.026290337, 0.01974...
# 5   [0.020555738, 0.046258952, 0.07994531, 0.06559...
# 6   [0.007772759, -0.020161236, -0.030871892, 0.03...
# 7   [0.033072267, 0.00800969, -0.008649761, 0.0593...
# 8   [-0.02511769, 0.026525773, 0.035119213, 0.0217...
# 9   [-0.029988721, 0.027915265, 0.05102884, 0.0762...
# 10  [-0.0013935389, -0.029477742, 0.060361575, 0.0...
# 11  [-0.0156262, 0.013531288, 0.0068710484, 0.0439...
# 12  [-0.013239748, 0.056249943, 0.049592096, 0.024...
# 13  [0.0023320434, 0.007970119, -0.0043752696, 0.0...
# 14  [-0.003940186, 0.03281184, 0.037894253, -0.001...
# 15  [-0.0034635423, 0.014160621, 0.0054746317, 0.0...
# 16  [-0.022906192, 0.018896202, 0.039818503, -0.00...
# 17  [0.033559643, -0.011711035, 0.066669725, 0.057...
# 18  [-0.049583487, 0.013832558, 0.048134927, 0.064...
# 19  [-0.034923047, -0.01194214, 0.07288671, 0.0649...
# 20  [0.0023331842, 0.003595982, 0.00849195, 0.0394...
# 21  [-0.009583157, 0.052212134, 0.039277166, -0.00...
# 22  [-0.016805353, -0.012922656, 0.045789868, 0.01...
# 23  [-0.007261706, -0.015481554, 0.061573215, 0.07...
# 24  [0.009259532, -0.0025729507, 0.05632367, 0.048...
# 25  [-0.012353403, -0.013732034, 0.03378189, 0.072...
# 26  [-0.0036769924, 0.02721682, 0.057656113, 0.052...
# 27  [-0.013200638, -0.018074032, 0.018252872, 0.06...
# 28  [0.01665234, -0.03443282, 0.042010985, 0.00497...
# 29  [0.022451421, 0.02940121, 0.04366181, 0.065120...
# 30  [0.016149512, 0.045446385, 0.034498878, 0.0492...
# 31  [0.013386441, 0.009099487, 0.04300885, 0.01524...
# 32  [-0.016581979, 0.031919338, 0.004651122, 0.020...
#
# [33 rows x 40 columns]

# %%
merged_df.to_csv('Question_Embedding_20241230.csv')
